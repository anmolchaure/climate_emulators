# %%
pip install scitools-iris
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scitools-iris
#   Downloading scitools_iris-3.4.1-py3-none-any.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 10.4 MB/s eta 0:00:00
# Collecting cf-units>=3.1
#   Downloading cf_units-3.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (544 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 544.7/544.7 KB 9.3 MB/s eta 0:00:00
# Collecting cartopy>=0.21
#   Downloading Cartopy-0.21.1.tar.gz (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 14.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: cftime>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from scitools-iris) (1.6.2)
# Requirement already satisfied: dask[array]>=2.26 in /usr/local/lib/python3.8/dist-packages (from scitools-iris) (2022.2.1)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 22.9 MB/s eta 0:00:00
# Requirement already satisfied: shapely!=1.8.3 in /usr/local/lib/python3.8/dist-packages (from scitools-iris) (2.0.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from scitools-iris) (1.7.3)
# Requirement already satisfied: netcdf4 in /usr/local/lib/python3.8/dist-packages (from scitools-iris) (1.6.2)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.8/dist-packages (from scitools-iris) (1.22.4)
# Collecting matplotlib>=3.5
#   Downloading matplotlib-3.7.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 52.4 MB/s eta 0:00:00
# Collecting pyshp>=2.1
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 KB 5.8 MB/s eta 0:00:00
# Collecting pyproj>=3.0.0
#   Downloading pyproj-3.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 30.2 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime==4.7.2
#   Downloading antlr4-python3-runtime-4.7.2.tar.gz (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 KB 13.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from cf-units>=3.1->scitools-iris) (2.11.3)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.8/dist-packages (from dask[array]>=2.26->scitools-iris) (6.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from dask[array]>=2.26->scitools-iris) (2.2.1)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.8/dist-packages (from dask[array]>=2.26->scitools-iris) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from dask[array]>=2.26->scitools-iris) (23.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.8/dist-packages (from dask[array]>=2.26->scitools-iris) (0.12.0)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from dask[array]>=2.26->scitools-iris) (2023.1.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.5->scitools-iris) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.5->scitools-iris) (5.10.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 KB 56.9 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 KB 26.9 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.5->scitools-iris) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.5->scitools-iris) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.5->scitools-iris) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.5->scitools-iris) (0.11.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.5->scitools-iris) (3.13.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.8/dist-packages (from partd>=0.3.10->dask[array]>=2.26->scitools-iris) (1.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from pyproj>=3.0.0->cartopy>=0.21->scitools-iris) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5->scitools-iris) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->cf-units>=3.1->scitools-iris) (2.0.1)
# Building wheels for collected packages: cartopy, antlr4-python3-runtime
#   Building wheel for cartopy (pyproject.toml) ... done
#   Created wheel for cartopy: filename=Cartopy-0.21.1-cp38-cp38-linux_x86_64.whl size=11127977 sha256=fb893c6065410ac48ae783b187435986194007a904b24b165142607b78c93aeb
#   Stored in directory: /root/.cache/pip/wheels/7c/ff/6f/09e4aa53f4e67d6498ef1d33dd4ea9c8c165817b9ddcc31d28
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.7.2-py3-none-any.whl size=140949 sha256=1fa7c35717613323dc442a268106853fb29d69bd2abf551a1358df0531c85794
#   Stored in directory: /root/.cache/pip/wheels/63/93/52/480c17789fbf685f5d0e33e83c311f4a844cd6e2f5cf036c03
# Successfully built cartopy antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, xxhash, pyshp, pyproj, fonttools, contourpy, matplotlib, cf-units, cartopy, scitools-iris
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# Successfully installed antlr4-python3-runtime-4.7.2 cartopy-0.21.1 cf-units-3.1.1 contourpy-1.0.7 fonttools-4.38.0 matplotlib-3.7.0 pyproj-3.4.1 pyshp-2.3.1 scitools-iris-3.4.1 xxhash-3.2.0

# %%
pip install utils
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting utils
#   Downloading utils-1.0.1-py2.py3-none-any.whl (21 kB)
# Installing collected packages: utils
# Successfully installed utils-1.0.1

# %%
pip install cis
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting cis
#   Downloading cis-1.7.4-py3-none-any.whl (22.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 18.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from cis) (1.22.4)
# Requirement already satisfied: netcdf4>=1.0 in /usr/local/lib/python3.8/dist-packages (from cis) (1.6.2)
# Requirement already satisfied: scitools-iris>=1.8.0 in /usr/local/lib/python3.8/dist-packages (from cis) (3.4.1)
# Requirement already satisfied: scipy>=0.15.0 in /usr/local/lib/python3.8/dist-packages (from cis) (1.7.3)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from cis) (1.15.0)
# Requirement already satisfied: matplotlib>=2.0 in /usr/local/lib/python3.8/dist-packages (from cis) (3.7.0)
# Requirement already satisfied: psutil>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from cis) (5.4.8)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.0->cis) (5.10.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.0->cis) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.0->cis) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.0->cis) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.0->cis) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.0->cis) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.0->cis) (7.1.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.0->cis) (4.38.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.0->cis) (3.0.9)
# Requirement already satisfied: cftime in /usr/local/lib/python3.8/dist-packages (from netcdf4>=1.0->cis) (1.6.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.8/dist-packages (from scitools-iris>=1.8.0->cis) (3.2.0)
# Requirement already satisfied: cartopy>=0.21 in /usr/local/lib/python3.8/dist-packages (from scitools-iris>=1.8.0->cis) (0.21.1)
# Requirement already satisfied: shapely!=1.8.3 in /usr/local/lib/python3.8/dist-packages (from scitools-iris>=1.8.0->cis) (2.0.1)
# Requirement already satisfied: dask[array]>=2.26 in /usr/local/lib/python3.8/dist-packages (from scitools-iris>=1.8.0->cis) (2022.2.1)
# Requirement already satisfied: cf-units>=3.1 in /usr/local/lib/python3.8/dist-packages (from scitools-iris>=1.8.0->cis) (3.1.1)
# Requirement already satisfied: pyproj>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from cartopy>=0.21->scitools-iris>=1.8.0->cis) (3.4.1)
# Requirement already satisfied: pyshp>=2.1 in /usr/local/lib/python3.8/dist-packages (from cartopy>=0.21->scitools-iris>=1.8.0->cis) (2.3.1)
# Requirement already satisfied: antlr4-python3-runtime==4.7.2 in /usr/local/lib/python3.8/dist-packages (from cf-units>=3.1->scitools-iris>=1.8.0->cis) (4.7.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from cf-units>=3.1->scitools-iris>=1.8.0->cis) (2.11.3)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from dask[array]>=2.26->scitools-iris>=1.8.0->cis) (2.2.1)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.8/dist-packages (from dask[array]>=2.26->scitools-iris>=1.8.0->cis) (1.3.0)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from dask[array]>=2.26->scitools-iris>=1.8.0->cis) (2023.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.8/dist-packages (from dask[array]>=2.26->scitools-iris>=1.8.0->cis) (6.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.8/dist-packages (from dask[array]>=2.26->scitools-iris>=1.8.0->cis) (0.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib>=2.0->cis) (3.13.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.8/dist-packages (from partd>=0.3.10->dask[array]>=2.26->scitools-iris>=1.8.0->cis) (1.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from pyproj>=3.0.0->cartopy>=0.21->scitools-iris>=1.8.0->cis) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->cf-units>=3.1->scitools-iris>=1.8.0->cis) (2.0.1)
# Installing collected packages: cis
# Successfully installed cis-1.7.4

# %%
pip install esem
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting esem
#   Downloading ESEm-1.1.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from esem) (1.22.4)
# Requirement already satisfied: tensorflow-probability in /usr/local/lib/python3.8/dist-packages (from esem) (0.19.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from esem) (1.7.3)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.8/dist-packages (from esem) (2.11.0)
# Requirement already satisfied: setuptools>=40.4 in /usr/local/lib/python3.8/dist-packages (from esem) (57.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from esem) (3.7.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from esem) (4.64.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->esem) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->esem) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->esem) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->esem) (7.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->esem) (5.10.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->esem) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->esem) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->esem) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->esem) (1.4.4)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (1.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (23.1.21)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (1.51.1)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (2.11.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (4.5.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (15.0.6.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (0.30.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (1.14.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (3.19.6)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (1.15.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (2.11.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (3.1.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (2.2.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability->esem) (0.1.8)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability->esem) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability->esem) (2.2.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow->esem) (0.38.4)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib->esem) (3.13.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->esem) (2.25.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->esem) (2.16.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->esem) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->esem) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->esem) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->esem) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->esem) (3.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->esem) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->esem) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->esem) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow->esem) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow->esem) (6.0.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow->esem) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow->esem) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow->esem) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow->esem) (2.10)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->esem) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow->esem) (3.2.2)
# Installing collected packages: esem
# Successfully installed esem-1.1.0

# %%
pip install esem
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: esem in /usr/local/lib/python3.8/dist-packages (1.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from esem) (3.7.0)
# Requirement already satisfied: tensorflow-probability in /usr/local/lib/python3.8/dist-packages (from esem) (0.19.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from esem) (1.22.4)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.8/dist-packages (from esem) (2.11.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from esem) (4.64.1)
# Requirement already satisfied: setuptools>=40.4 in /usr/local/lib/python3.8/dist-packages (from esem) (57.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from esem) (1.7.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->esem) (4.38.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->esem) (5.10.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->esem) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->esem) (7.1.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->esem) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->esem) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->esem) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->esem) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->esem) (1.4.4)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (0.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (1.14.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (3.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (3.19.6)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (2.2.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (2.11.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (23.1.21)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (2.11.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (3.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (1.15.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (2.11.2)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (0.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (0.30.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (1.4.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (15.0.6.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (1.51.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow->esem) (4.5.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability->esem) (0.1.8)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability->esem) (2.2.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from tensorflow-probability->esem) (4.4.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow->esem) (0.38.4)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib->esem) (3.13.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->esem) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->esem) (2.25.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->esem) (2.16.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->esem) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->esem) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->esem) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow->esem) (3.4.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->esem) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->esem) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->esem) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow->esem) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow->esem) (6.0.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow->esem) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow->esem) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow->esem) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow->esem) (2.10)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->esem) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow->esem) (3.2.2)

# %%
# !pip install tensorflow==2.2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow==2.2.0
#   Downloading tensorflow-2.2.0-cp38-cp38-manylinux2010_x86_64.whl (516.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.3/516.3 MB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (1.15.0)
# Collecting h5py<2.11.0,>=2.10.0
#   Downloading h5py-2.10.0-cp38-cp38-manylinux1_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 23.0 MB/s eta 0:00:00
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (1.51.1)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (3.3.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (1.4.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (3.19.6)
# Collecting keras-preprocessing>=1.1.0
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (0.38.4)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (1.14.1)
# Collecting tensorboard<2.3.0,>=2.2.0
#   Downloading tensorboard-2.2.2-py3-none-any.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 43.2 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (2.2.0)
# Collecting tensorflow-estimator<2.3.0,>=2.2.0
#   Downloading tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.6/454.6 KB 30.3 MB/s eta 0:00:00
# Collecting scipy==1.4.1
#   Downloading scipy-1.4.1-cp38-cp38-manylinux1_x86_64.whl (26.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.0/26.0 MB 31.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (1.22.4)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow==2.2.0) (1.6.3)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (57.4.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2.25.1)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.35.0-py2.py3-none-any.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.9/152.9 KB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.2.8)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.4-py3-none-any.whl (10 kB)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (6.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.13.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.2.2)
# Installing collected packages: tensorflow-estimator, scipy, keras-preprocessing, h5py, gast, cachetools, google-auth, tensorboard, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.11.0
#     Uninstalling tensorflow-estimator-2.11.0:
#       Successfully uninstalled tensorflow-estimator-2.11.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.3.0
#     Uninstalling cachetools-5.3.0:
#       Successfully uninstalled cachetools-5.3.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.16.0
#     Uninstalling google-auth-2.16.0:
#       Successfully uninstalled google-auth-2.16.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.2
#     Uninstalling tensorboard-2.11.2:
#       Successfully uninstalled tensorboard-2.11.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.11.0
#     Uninstalling tensorflow-2.11.0:
#       Successfully uninstalled tensorflow-2.11.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xarray-einstats 0.5.1 requires scipy>=1.6, but you have scipy 1.4.1 which is incompatible.
# plotnine 0.8.0 requires scipy>=1.5.0, but you have scipy 1.4.1 which is incompatible.
# jaxlib 0.3.25+cuda11.cudnn805 requires scipy>=1.5, but you have scipy 1.4.1 which is incompatible.
# jax 0.3.25 requires scipy>=1.5, but you have scipy 1.4.1 which is incompatible.
# google-api-core 2.11.0 requires google-auth<3.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# Successfully installed cachetools-4.2.4 gast-0.3.3 google-auth-1.35.0 h5py-2.10.0 keras-preprocessing-1.1.2 scipy-1.4.1 tensorboard-2.2.2 tensorflow-2.2.0 tensorflow-estimator-2.2.0

# %%
# !pip install scitools-iris
# !pip install iris-sample-data
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scitools-iris in /usr/local/lib/python3.8/dist-packages (3.4.1)
# Requirement already satisfied: netcdf4 in /usr/local/lib/python3.8/dist-packages (from scitools-iris) (1.6.2)
# Requirement already satisfied: shapely!=1.8.3 in /usr/local/lib/python3.8/dist-packages (from scitools-iris) (2.0.1)
# Requirement already satisfied: cartopy>=0.21 in /usr/local/lib/python3.8/dist-packages (from scitools-iris) (0.21.1)
# Requirement already satisfied: cftime>=1.5.0 in /usr/local/lib/python3.8/dist-packages (from scitools-iris) (1.6.2)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.8/dist-packages (from scitools-iris) (1.22.4)
# Requirement already satisfied: dask[array]>=2.26 in /usr/local/lib/python3.8/dist-packages (from scitools-iris) (2022.2.1)
# Requirement already satisfied: matplotlib>=3.5 in /usr/local/lib/python3.8/dist-packages (from scitools-iris) (3.7.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.8/dist-packages (from scitools-iris) (3.2.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from scitools-iris) (1.4.1)
# Requirement already satisfied: cf-units>=3.1 in /usr/local/lib/python3.8/dist-packages (from scitools-iris) (3.1.1)
# Requirement already satisfied: pyproj>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from cartopy>=0.21->scitools-iris) (3.4.1)
# Requirement already satisfied: pyshp>=2.1 in /usr/local/lib/python3.8/dist-packages (from cartopy>=0.21->scitools-iris) (2.3.1)
# Requirement already satisfied: antlr4-python3-runtime==4.7.2 in /usr/local/lib/python3.8/dist-packages (from cf-units>=3.1->scitools-iris) (4.7.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from cf-units>=3.1->scitools-iris) (2.11.3)
# Requirement already satisfied: cloudpickle>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from dask[array]>=2.26->scitools-iris) (2.2.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from dask[array]>=2.26->scitools-iris) (23.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.8/dist-packages (from dask[array]>=2.26->scitools-iris) (6.0)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from dask[array]>=2.26->scitools-iris) (2023.1.0)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.8/dist-packages (from dask[array]>=2.26->scitools-iris) (1.3.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.8/dist-packages (from dask[array]>=2.26->scitools-iris) (0.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.5->scitools-iris) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.5->scitools-iris) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.5->scitools-iris) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.5->scitools-iris) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.5->scitools-iris) (5.10.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.5->scitools-iris) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.5->scitools-iris) (7.1.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.5->scitools-iris) (0.11.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.5->scitools-iris) (3.13.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.8/dist-packages (from partd>=0.3.10->dask[array]>=2.26->scitools-iris) (1.0.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from pyproj>=3.0.0->cartopy>=0.21->scitools-iris) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5->scitools-iris) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->cf-units>=3.1->scitools-iris) (2.0.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting iris-sample-data
#   Downloading iris_sample_data-2.4.0-py3-none-any.whl (23.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 13.4 MB/s eta 0:00:00
# Installing collected packages: iris-sample-data
# Successfully installed iris-sample-data-2.4.0

# %%
# !apt-get -qq install python-cartopy python3-cartopy
# !pip uninstall -y shapely    # cartopy and shapely aren't friends (early 2020)
# !pip install shapely --no-binary shapely
# Out:
# E: Unable to locate package python-cartopy
# Found existing installation: shapely 2.0.1
# Uninstalling shapely-2.0.1:
#   Successfully uninstalled shapely-2.0.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting shapely
#   Downloading shapely-2.0.1.tar.gz (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.5/275.5 KB 6.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#   WARNING: Generating metadata for package shapely produced metadata for project name unknown. Fix your #egg=shapely fragments.
# Discarding https://files.pythonhosted.org/packages/10/a7/de139da3ce303101c357a9ba801328cba85cf6ace157da31a4007bca85e4/shapely-2.0.1.tar.gz#sha256=66a6b1a3e72ece97fc85536a281476f9b7794de2e646ca8a4517e2e3c1446893 (from https://pypi.org/simple/shapely/) (requires-python:>=3.7): Requested unknown from https://files.pythonhosted.org/packages/10/a7/de139da3ce303101c357a9ba801328cba85cf6ace157da31a4007bca85e4/shapely-2.0.1.tar.gz#sha256=66a6b1a3e72ece97fc85536a281476f9b7794de2e646ca8a4517e2e3c1446893 has inconsistent name: filename has 'shapely', but metadata has 'unknown'
#   Downloading shapely-2.0.0.tar.gz (274 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.5/274.5 KB 24.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#   WARNING: Generating metadata for package shapely produced metadata for project name unknown. Fix your #egg=shapely fragments.
# Discarding https://files.pythonhosted.org/packages/61/76/6e635cc4ba33e8c170ef5934dad5c269dc5cb9607e878efb2aba12f78361/shapely-2.0.0.tar.gz#sha256=11f1b1231a6c04213fb1226c6968d1b1b3b369ec42d1e9655066af87631860ea (from https://pypi.org/simple/shapely/) (requires-python:>=3.7): Requested unknown from https://files.pythonhosted.org/packages/61/76/6e635cc4ba33e8c170ef5934dad5c269dc5cb9607e878efb2aba12f78361/shapely-2.0.0.tar.gz#sha256=11f1b1231a6c04213fb1226c6968d1b1b3b369ec42d1e9655066af87631860ea has inconsistent name: filename has 'shapely', but metadata has 'unknown'
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /packages/92/2e/a8bbe3c6b414c3c61c4b639ab16d5b1f9c4c4095817d417b503413e613c0/Shapely-1.8.5.post1.tar.gz
#   Downloading Shapely-1.8.5.post1.tar.gz (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 KB 5.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   WARNING: Missing build requirements in pyproject.toml for shapely from https://files.pythonhosted.org/packages/92/2e/a8bbe3c6b414c3c61c4b639ab16d5b1f9c4c4095817d417b503413e613c0/Shapely-1.8.5.post1.tar.gz#sha256=ef3be705c3eac282a28058e6c6e5503419b250f482320df2172abcbea642c831.
#   WARNING: The project does not specify a build backend, and pip cannot fall back to setuptools without 'wheel'.
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: shapely
#   Building wheel for shapely (pyproject.toml) ... done
#   Created wheel for shapely: filename=Shapely-1.8.5.post1-cp38-cp38-linux_x86_64.whl size=971192 sha256=b53095cdd6da189aad86c5218e7e8b8b4125b7aebdabda744c55a177e53f9b2e
#   Stored in directory: /root/.cache/pip/wheels/1e/b7/86/5badb596b4dcdcb8f0fa49a4b83e7d934681843c6dc406b16d
# Successfully built shapely
# Installing collected packages: shapely
# Successfully installed shapely-1.8.5.post1

# %%
# !apt-get install libproj-dev proj-data proj-bin
# !apt-get install libgeos-dev
# !pip install cython
# !pip install cartopy
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libproj-dev is already the newest version (7.2.1-1~focal0).
# libproj-dev set to manually installed.
# proj-data is already the newest version (7.2.1-1~focal0).
# proj-data set to manually installed.
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   proj-bin
# 0 upgraded, 1 newly installed, 0 to remove and 21 not upgraded.
# Need to get 170 kB of archives.
# After this operation, 485 kB of additional disk space will be used.
# Get:1 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal/main amd64 proj-bin amd64 7.2.1-1~focal0 [170 kB]
# Fetched 170 kB in 1s (283 kB/s)
# Selecting previously unselected package proj-bin.
# (Reading database ... 128126 files and directories currently installed.)
# Preparing to unpack .../proj-bin_7.2.1-1~focal0_amd64.deb ...
# Unpacking proj-bin (7.2.1-1~focal0) ...
# Setting up proj-bin (7.2.1-1~focal0) ...
# Processing triggers for man-db (2.9.1-1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libgeos-dev is already the newest version (3.9.1-1~focal0).
# libgeos-dev set to manually installed.
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: cython in /usr/local/lib/python3.8/dist-packages (0.29.33)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: cartopy in /usr/local/lib/python3.8/dist-packages (0.21.1)
# Requirement already satisfied: matplotlib>=3.1 in /usr/local/lib/python3.8/dist-packages (from cartopy) (3.7.0)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.8/dist-packages (from cartopy) (1.22.4)
# Requirement already satisfied: shapely>=1.6.4 in /usr/local/lib/python3.8/dist-packages (from cartopy) (1.8.5.post1)
# Requirement already satisfied: pyshp>=2.1 in /usr/local/lib/python3.8/dist-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from cartopy) (3.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1->cartopy) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1->cartopy) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1->cartopy) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1->cartopy) (7.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1->cartopy) (5.10.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1->cartopy) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1->cartopy) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1->cartopy) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1->cartopy) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from pyproj>=3.0.0->cartopy) (2022.12.7)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.1->cartopy) (3.13.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1->cartopy) (1.15.0)

# %%
import iris

#from utils import get_bc_ppe_data

from esem import cnn_model
from esem.utils import get_random_params

import iris.quickplot as qplt
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
"""
Tools for loading / downloading the example data files
"""
import os
import urllib.request


def normalize(x): # a function that calculates normalization 
    return (x - x.min())/(x.max() - x.min())


def _download_aeronet(output_file): #(aeronet : AErosol RObotic NETwork)
    # Request daily 2017 AAOD for all stations
    target_url = "https://aeronet.gsfc.nasa.gov/cgi-bin/print_web_data_inv_v3?year=2017&month=1&day=1&year2=2018&month2=1&day2=1&product=TAB&AVG=20&HYB15=1&if_no_html=1"
    response = urllib.request.urlopen(target_url)
    # Discard the first line which isn't standard AeroNet
    _ = next(response)
    with open(output_file, 'w') as f:
        for line in response:
            f.write(line.decode('utf-8'))


def get_aeronet_data(cache_path='.'):
    import cis
    from cis.data_io.aeronet import AERONET_HEADER_LENGTH

    aerocom_cache = os.path.join(cache_path, 'aerocom_2017_global.lev15')

    if not os.path.isfile(aerocom_cache):
        _download_aeronet(aerocom_cache)

    # Fix the header length which seems to be different for downloaded files...
    AERONET_HEADER_LENGTH["AERONET/3"] = 6

    # TODO: I might want to interpolate between 440 and 630nm to get 550nm...
    aaod = cis.read_data(aerocom_cache, 'Absorption_AOD440nm')
    # Pop off the altitude coordinate which we're not interested in
    _ = aaod._coords.pop(aaod._coords.index(aaod.coord('altitude')))
    return aaod


def get_bc_ppe_data(cache_path='.', dre=False, normalize_params=True):
    """
    Load the example BC PPE AAOD data and parameters, downloading if not present

    :param str cache_path: Path to load/store the PPE data
    :param bool dre: Output the Direct Radiative Effect data also
    :param bool normalize_params: Normalize the PPE parameters between 0.-1.
    :return:
    """
    import pandas as pd
    import numpy as np
    import cis

    bc_ppe_cache = os.path.join(cache_path, 'BC_PPE_PD_AAOD_monthly.nc')

    if not os.path.isfile(bc_ppe_cache):
        urllib.request.urlretrieve("https://zenodo.org/record/3856645/files/BC_PPE_PD_AAOD_monthly.nc?download=1", bc_ppe_cache)

    params_cache = os.path.join(cache_path, 'aerocommmppe_bcdesign.csv')
    if not os.path.isfile(params_cache):
        urllib.request.urlretrieve("https://zenodo.org/record/3856645/files/aerocommmppe_bcdesign.csv?download=1", params_cache)

    ppe_params = pd.read_csv(params_cache)
    ppe_aaod = cis.read_data(bc_ppe_cache, 'ABS_2D_550nm', 'NetCDF_Gridded')
    # Ensure the job dimension is at the front
    ppe_aaod.transpose((1, 0, 2, 3))
    
    if normalize_params:
        # These scaling parameters are log-uniformly distributed
        ppe_params[['BCnumber', 'Wetdep']] = np.log(ppe_params[['BCnumber', 'Wetdep']])
        ppe_params = ppe_params.apply(normalize, axis=0)
    
    if dre:
        ppe_dre_cache = os.path.join(cache_path, 'BC_PPE_PD_FORCING_monthly.nc')
        if not os.path.isfile(ppe_dre_cache):
            urllib.request.urlretrieve("https://zenodo.org/record/3856645/files/BC_PPE_PD_FORCING_monthly.nc?download=1", ppe_dre_cache)

        ppe_dre = cis.read_data(ppe_dre_cache, 'FSW_TOTAL_TOP', 'NetCDF_Gridded')        
        return ppe_params, ppe_aaod, ppe_dre
    else:
        return ppe_params, ppe_aaod

def get_crm_data(cache_path='.', preprocess=True):
    """
    Load the example cloud-resolving model data, download if not present.
    :param str cache_path: Path to load/store the data
    :param bool preprocess: Whether or not to clean and concatenate the data
    :return:
    """
    import pandas as pd
    import os
    import urllib.request

    N1_200_cache = os.path.join(cache_path, 'NARVAL1_1hr_200cdnc.csv')
    if not os.path.isfile(N1_200_cache):
        urllib.request.urlretrieve("https://zenodo.org/record/4323300/files/NARVAL1_1hr_200cdnc.csv?download=1", N1_200_cache)
        
        
    N1_20_cache = os.path.join(cache_path, 'NARVAL1_1hr_20cdnc.csv')
    if not os.path.isfile(N1_20_cache):
        urllib.request.urlretrieve("https://zenodo.org/record/4323300/files/NARVAL1_1hr_20cdnc.csv?download=1", N1_20_cache)
        
    N1_20_shal_cache = os.path.join(cache_path, 'NARVAL1_1hr_20cdnc_shal.csv')
    if not os.path.isfile(N1_20_shal_cache):
        urllib.request.urlretrieve("https://zenodo.org/record/4323300/files/NARVAL1_1hr_20cdnc_shal.csv?download=1", N1_20_shal_cache)
        
        
    N1_200_shal_cache = os.path.join(cache_path, 'NARVAL1_1hr_200cdnc_shal.csv')
    if not os.path.isfile(N1_200_shal_cache):
        urllib.request.urlretrieve("https://zenodo.org/record/4323300/files/NARVAL1_1hr_200cdnc_shal.csv?download=1", N1_200_shal_cache)

    
    if preprocess:
        df20 = pd.read_csv(N1_20_shal_cache).set_index('time').drop(columns='plev')
        df200 = pd.read_csv(N1_200_shal_cache).set_index('time').drop(columns='plev')

        new_df = pd.concat([df20, df200]).reset_index().drop(columns='time')

        return new_df
    
    else:
        df20 = pd.read_csv('NARVAL1_1hr_20cdnc_shal.csv')
        df200 = pd.read_csv('NARVAL1_1hr_200cdnc_shal.csv')
        return df20, df200

# %%
ppe_params, ppe_aaod = get_bc_ppe_data()

# %%
## Ensure the time dimension is last - this is treated as the color 'channel'
ppe_aaod.transpose((0,2,3,1))

# %%
n_test = 5

X_test, X_train = ppe_params[:n_test], ppe_params[n_test:]
Y_test, Y_train = ppe_aaod[:n_test], ppe_aaod[n_test:]

# %%
Y_train
# Out:
# <iris 'Cube' of Absorption optical thickness - total 550nm / (1) (job: 34; latitude: 96; longitude: 192; time: 12)>

# %%
model = cnn_model(X_train, Y_train)

# %%
model.model.model.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3)]               0
# _________________________________________________________________
# dense (Dense)                (None, 221184)            884736
# _________________________________________________________________
# reshape (Reshape)            (None, 96, 192, 12)       0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 96, 192, 12)       2172
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 96, 192, 12)       2172
# =================================================================
# Total params: 889,080
# Trainable params: 889,080
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.train()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 3s 696ms/step - loss: 1.1383 - val_loss: 0.4636
# Epoch 2/100
# 4/4 [==============================] - 2s 514ms/step - loss: 1.1272 - val_loss: 0.4568
# Epoch 3/100
# 4/4 [==============================] - 2s 426ms/step - loss: 1.1125 - val_loss: 0.4561
# Epoch 4/100
# 4/4 [==============================] - 1s 257ms/step - loss: 1.0864 - val_loss: 0.4596
# Epoch 5/100
# 4/4 [==============================] - 1s 256ms/step - loss: 1.0538 - val_loss: 0.4632
# 4/4 [==============================] - 2s 521ms/step - loss: 0.2849 - val_loss: 0.0754
# Epoch 95/100
# 4/4 [==============================] - 1s 260ms/step - loss: 0.2844 - val_loss: 0.0780
# Epoch 96/100
# 4/4 [==============================] - 1s 262ms/step - loss: 0.2849 - val_loss: 0.0720
# Epoch 97/100
# 4/4 [==============================] - 1s 255ms/step - loss: 0.2843 - val_loss: 0.0763
# Epoch 98/100
# 4/4 [==============================] - 1s 261ms/step - loss: 0.2843 - val_loss: 0.0677
# Epoch 99/100
# 4/4 [==============================] - 2s 400ms/step - loss: 0.2844 - val_loss: 0.0737
# Epoch 100/100
# 4/4 [==============================] - 2s 443ms/step - loss: 0.2842 - val_loss: 0.0727

# %%
m, v = model.predict(X_test.to_numpy())

# %%
## TODO: Tidy this up a bit
plt.figure(figsize=(12, 8))
plt.subplot(2,2,1)
qplt.pcolormesh(m[0].collapsed('time', iris.analysis.MEAN))
plt.gca().set_title('Predicted')
plt.gca().coastlines()

plt.subplot(2,2,2)
qplt.pcolormesh(Y_test[0].collapsed('time', iris.analysis.MEAN))
plt.gca().set_title('Test')
plt.gca().coastlines()

plt.subplot(2,2,3)
qplt.pcolormesh((m.collapsed(['sample', 'time'], iris.analysis.MEAN)-Y_test.collapsed(['job', 'time'], iris.analysis.MEAN)), cmap='RdBu_r', vmin=-0.01, vmax=0.01)
plt.gca().coastlines()
plt.gca().set_title('Difference')
# Out:
# /usr/local/lib/python3.8/dist-packages/iris/coords.py:2047: UserWarning: Coordinate 'longitude' is not bounded, guessing contiguous bounds.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/iris/coords.py:2047: UserWarning: Coordinate 'latitude' is not bounded, guessing contiguous bounds.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/iris/coords.py:2047: UserWarning: Coordinate 'longitude' is not bounded, guessing contiguous bounds.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/iris/coords.py:2047: UserWarning: Coordinate 'latitude' is not bounded, guessing contiguous bounds.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/iris/coords.py:2226: UserWarning: Cannot check if coordinate is contiguous: Invalid operation for 'sample', with 0 bound(s). Contiguous bounds are only defined for 1D coordinates with 2 bounds. Metadata may not be fully descriptive for 'sample'. Ignoring bounds.
#   warnings.warn(msg.format(str(exc), self.name()))
# /usr/local/lib/python3.8/dist-packages/iris/coords.py:2226: UserWarning: Cannot check if coordinate is contiguous: Invalid operation for 'job', with 0 bound(s). Contiguous bounds are only defined for 1D coordinates with 2 bounds. Metadata may not be fully descriptive for 'job'. Ignoring bounds.
#   warnings.warn(msg.format(str(exc), self.name()))
# /usr/local/lib/python3.8/dist-packages/iris/coords.py:2047: UserWarning: Coordinate 'longitude' is not bounded, guessing contiguous bounds.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/iris/coords.py:2047: UserWarning: Coordinate 'latitude' is not bounded, guessing contiguous bounds.
#   warnings.warn(
# Text(0.5, 1.0, 'Difference')
# /usr/local/lib/python3.8/dist-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/110m_physical/ne_110m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %%
m, sd = model.batch_stats(get_random_params(3, int(1e5)), batch_size=1000)
# Out:
#   0%|          | 0/100000 [00:00<?, ?sample/s]
# <tqdm.auto.tqdm object at 0x7f0d5fca6c40>
